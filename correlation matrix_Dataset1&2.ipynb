# %%
import pandas as pd

# %%
# Dataset 1
df1 = pd.read_csv("data/processed_dataset1.csv")

# %%
df1
# Out:
#         Unnamed: 0 trans_date_trans_time        cc_num  \
# 0                0       6/21/2020 12:14  2.291160e+15
# 1                1       6/21/2020 12:14  3.573030e+15
# 2                2       6/21/2020 12:14  3.598220e+15
# 3                3       6/21/2020 12:15  3.591920e+15
# 4                4       6/21/2020 12:15  3.526830e+15
# ...            ...                   ...           ...
# 555714      555714      12/31/2020 23:59  3.056060e+13
# 555715      555715      12/31/2020 23:59  3.556610e+15
# 555716      555716      12/31/2020 23:59  6.011720e+15
# 555717      555717      12/31/2020 23:59  4.079770e+12
# 555718      555718      12/31/2020 23:59  4.170690e+15
#
#                                     merchant        category     amt    first  \
# 0                      fraud_Kirlin and Sons   personal_care    2.86     Jeff
# 1                       fraud_Sporer-Keebler   personal_care   29.84   Joanne
# ...

# %%
corrMatrix1 = df1.corr()
print (corrMatrix1)
# Out:
# C:\Users\Grace\AppData\Local\Temp\ipykernel_5408\131531285.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corrMatrix = df.corr()
#                                 Unnamed: 0    cc_num       amt       zip  \
# Unnamed: 0                        1.000000 -0.000823 -0.001137  0.001479
# cc_num                           -0.000823  1.000000  0.001963  0.041610
# amt                              -0.001137  0.001963  1.000000  0.002310
# zip                               0.001479  0.041610  0.002310  1.000000
# lat                               0.000336 -0.057512  0.002339 -0.115173
# long                             -0.001558 -0.048783 -0.002046 -0.909942
# city_pop                         -0.000794 -0.009414  0.002760  0.075571
# unix_time                         0.997054 -0.000810 -0.000974  0.001395
# ...

# %%
import seaborn as sn
import matplotlib.pyplot as plt

# %%
sn.heatmap(corrMatrix1,annot=True)
plt.show()

# %%
# Dataset 2
df2 = pd.read_csv("data/processed_dataset2.csv")

# %%
df2
# Out:
#      Transaction Date and Time  Transaction Amount        Cardholder Name  \
# 0          2022-09-24 13:54:27              285.88            Shray Soman
# 1          2020-07-24 11:20:13             1777.32         Lakshit Bakshi
# 2          2023-03-18 01:05:36             3939.01             Riya Bobal
# 3          2021-01-07 21:53:04              376.44  Mohanlal Balakrishnan
# 4          2021-12-16 06:22:24             1687.33            Mannat Rout
# ...                        ...                 ...                    ...
# 7995       2020-12-17 20:36:48             2214.15         Lakshay Khatri
# 7996       2022-07-04 05:19:11              675.97        Dharmajan Salvi
# 7997       2022-08-14 19:14:45              918.28              Alia Sane
# 7998       2021-05-16 18:21:52             3035.31            Chirag Rege
# 7999       2023-06-14 06:12:26             3354.36              Alia Bose
#
#                       Card Number (Hashed or Encrypted)  \
# ...

# %%
corrMatrix2 = df2.corr()
print (corrMatrix2)
# Out:
#                                 Transaction Amount  \
# Transaction Amount                        1.000000
# Merchant Category Code (MCC)              0.014796
# Transaction Response Code                 0.010757
# Fraud Flag or Label                      -0.009679
# Categorized_times                         0.009441
# Categorized_trasaction_purpose           -0.004323
#
#                                 Merchant Category Code (MCC)  \
# Transaction Amount                                  0.014796
# Merchant Category Code (MCC)                        1.000000
# Transaction Response Code                           0.007705
# Fraud Flag or Label                                 0.012742
# Categorized_times                                  -0.002992
# Categorized_trasaction_purpose                     -0.097491
#
#                                 Transaction Response Code  \
# Transaction Amount                               0.010757
# ...

# %%
sn.heatmap(corrMatrix2,annot=True)
plt.show()
