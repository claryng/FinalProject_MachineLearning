# %%
import pandas as pd

# %%
df = pd.read_csv("final_dataset3/fraudTest.csv")

# %%
df
# Out:
#         Unnamed: 0 trans_date_trans_time            cc_num  \
# 0                0   2020-06-21 12:14:25  2291163933867244
# 1                1   2020-06-21 12:14:33  3573030041201292
# 2                2   2020-06-21 12:14:53  3598215285024754
# 3                3   2020-06-21 12:15:15  3591919803438423
# 4                4   2020-06-21 12:15:17  3526826139003047
# ...            ...                   ...               ...
# 555714      555714   2020-12-31 23:59:07    30560609640617
# 555715      555715   2020-12-31 23:59:09  3556613125071656
# 555716      555716   2020-12-31 23:59:15  6011724471098086
# 555717      555717   2020-12-31 23:59:24     4079773899158
# 555718      555718   2020-12-31 23:59:34  4170689372027579
#
#                                     merchant        category     amt    first  \
# 0                      fraud_Kirlin and Sons   personal_care    2.86     Jeff
# 1                       fraud_Sporer-Keebler   personal_care   29.84   Joanne
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'trans_date_trans_time', 'cc_num', 'merchant', 'category',
#        'amt', 'first', 'last', 'gender', 'street', 'city', 'state', 'zip',
#        'lat', 'long', 'city_pop', 'job', 'dob', 'trans_num', 'unix_time',
#        'merch_lat', 'merch_long', 'is_fraud'],
#       dtype='object')

# %%
df["Time"] = pd.to_datetime(df["trans_date_trans_time"], format='%Y-%m-%d %H:%M:%S')

# %%
df.Time
# Out:
# 0        2020-06-21 12:14:25
# 1        2020-06-21 12:14:33
# 2        2020-06-21 12:14:53
# 3        2020-06-21 12:15:15
# 4        2020-06-21 12:15:17
#                  ...
# 555714   2020-12-31 23:59:07
# 555715   2020-12-31 23:59:09
# 555716   2020-12-31 23:59:15
# 555717   2020-12-31 23:59:24
# 555718   2020-12-31 23:59:34
# Name: Time, Length: 555719, dtype: datetime64[ns]

# %%
times = pd.Series(['00:00:00','06:00:00','12:00:00','18:00:00'])

# %%
times = pd.to_datetime(times)

# %%
times = times.dt.time

# %%
times
# Out:
# 0    00:00:00
# 1    06:00:00
# 2    12:00:00
# 3    18:00:00
# dtype: object

# %%
recorded_times = df.Time.dt.time

# %%
recorded_times
# Out:
# 0         12:14:25
# 1         12:14:33
# 2         12:14:53
# 3         12:15:15
# 4         12:15:17
#             ...
# 555714    23:59:07
# 555715    23:59:09
# 555716    23:59:15
# 555717    23:59:24
# 555718    23:59:34
# Name: Time, Length: 555719, dtype: object

# %%
r, c = df.shape

# %%
r
# Out:
# 555719

# %%
c
# Out:
# 24

# %%
def categorize_time(x):
    if times[0] <= x < times[1]:
        return 1
    if times[1] <= x < times[2]:
        return 2
    if times[2] <= x < times[3]:
        return 3
    else:
        return 4

# %%
df["Recorded_times"] = recorded_times

# %%
df.drop(columns=["Time", "Times"])
# Out:
#         Unnamed: 0 trans_date_trans_time            cc_num  \
# 0                0   2020-06-21 12:14:25  2291163933867244
# 1                1   2020-06-21 12:14:33  3573030041201292
# 2                2   2020-06-21 12:14:53  3598215285024754
# 3                3   2020-06-21 12:15:15  3591919803438423
# 4                4   2020-06-21 12:15:17  3526826139003047
# ...            ...                   ...               ...
# 555714      555714   2020-12-31 23:59:07    30560609640617
# 555715      555715   2020-12-31 23:59:09  3556613125071656
# 555716      555716   2020-12-31 23:59:15  6011724471098086
# 555717      555717   2020-12-31 23:59:24     4079773899158
# 555718      555718   2020-12-31 23:59:34  4170689372027579
#
#                                     merchant        category     amt    first  \
# 0                      fraud_Kirlin and Sons   personal_care    2.86     Jeff
# 1                       fraud_Sporer-Keebler   personal_care   29.84   Joanne
# ...

# %%
categorized_times = df["Recorded_times"].apply(categorize_time)

# %%
df["Categorized_times"] = categorized_times

# %%
df
# Out:
#         Unnamed: 0 trans_date_trans_time            cc_num  \
# 0                0   2020-06-21 12:14:25  2291163933867244
# 1                1   2020-06-21 12:14:33  3573030041201292
# 2                2   2020-06-21 12:14:53  3598215285024754
# 3                3   2020-06-21 12:15:15  3591919803438423
# 4                4   2020-06-21 12:15:17  3526826139003047
# ...            ...                   ...               ...
# 555714      555714   2020-12-31 23:59:07    30560609640617
# 555715      555715   2020-12-31 23:59:09  3556613125071656
# 555716      555716   2020-12-31 23:59:15  6011724471098086
# 555717      555717   2020-12-31 23:59:24     4079773899158
# 555718      555718   2020-12-31 23:59:34  4170689372027579
#
#                                     merchant        category     amt    first  \
# 0                      fraud_Kirlin and Sons   personal_care    2.86     Jeff
# 1                       fraud_Sporer-Keebler   personal_care   29.84   Joanne
# ...

# %%
def categorize_transaction_purpose(x):
    x = x.split("_")
    for i in x:
        if i in "kid kids pet pets shopping shop daily clothes household home grocery":
            return 1
        if i in "education entertainment transportation dining travel":
            return 2
        if i in "health fitness care":
            return 3
    return 4

# %%
categorized_transaction_purpose = df["category"].apply(categorize_transaction_purpose)

# %%
df["Categorized_trasaction_purpose"] = categorized_transaction_purpose

# %%
df
# Out:
#         Unnamed: 0 trans_date_trans_time            cc_num  \
# 0                0   2020-06-21 12:14:25  2291163933867244
# 1                1   2020-06-21 12:14:33  3573030041201292
# 2                2   2020-06-21 12:14:53  3598215285024754
# 3                3   2020-06-21 12:15:15  3591919803438423
# 4                4   2020-06-21 12:15:17  3526826139003047
# ...            ...                   ...               ...
# 555714      555714   2020-12-31 23:59:07    30560609640617
# 555715      555715   2020-12-31 23:59:09  3556613125071656
# 555716      555716   2020-12-31 23:59:15  6011724471098086
# 555717      555717   2020-12-31 23:59:24     4079773899158
# 555718      555718   2020-12-31 23:59:34  4170689372027579
#
#                                     merchant        category     amt    first  \
# 0                      fraud_Kirlin and Sons   personal_care    2.86     Jeff
# 1                       fraud_Sporer-Keebler   personal_care   29.84   Joanne
# ...
